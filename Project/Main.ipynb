# %%
# Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import csv
import os

# %%
# Find path

Currentpath = os.getcwd()
Currentpath
# Out:
# '/Users/Younes/Desktop/Useful-Repository-master/Project'

# %%
# Read CSV CMS Enrollement file

df1 = pd.read_csv("Enrollement.csv") 
df1.head()
# Out:
#   Contract Number  Plan ID  SSA State County Code  FIPS State County Code  \
# 0           E0654      801                   2275                     NaN
# 1           E0654      801                  58160                     NaN
# 2           E0654      801                  56010                     NaN
# 3           E0654      801                   2198                     NaN
# 4           E0654      801                   1000                  1001.0
#
#   State   County Enrollment
# 0   NaN      NaN          *
# 1   NaN      NaN          *
# 2   NaN      NaN          *
# 3   NaN      NaN          *
# 4    AL  Autauga          *

# %%
# Columns 1

df1.columns
# Out:
# Index(['Contract Number', 'Plan ID', 'SSA State County Code',
#        'FIPS State County Code', 'State', 'County', 'Enrollment'],
#       dtype='object')

# %%
New_df = df1[['FIPS State County Code', 'State', 'County', 'Enrollment']]
New_df.head()
# Out:
#    FIPS State County Code State   County Enrollment
# 0                     NaN   NaN      NaN          *
# 1                     NaN   NaN      NaN          *
# 2                     NaN   NaN      NaN          *
# 3                     NaN   NaN      NaN          *
# 4                  1001.0    AL  Autauga          *

# %%
# Clean Enrollement Dataframe. Remove '*' and Nan

New_CMS = New_df.dropna(how='any')
New_CMS = New_df[df1.Enrollment!= '*']
New_CMS['Enrollment'] = pd.to_numeric(New_CMS['Enrollment'])
New_CMS.head()
# Out:
# /Users/Younes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#     FIPS State County Code State                County  Enrollment
# 5                   1003.0    AL               Baldwin          14
# 73                  2020.0    AK             Anchorage         152
# 78                  2090.0    AK  Fairbanks North Star          99
# 81                  2122.0    AK       Kenai Peninsula          36
# 85                  2170.0    AK     Matanuska-Susitna          66

# %%
# Groupy state and county

Cms_Enrollment = New_CMS.groupby(['FIPS State County Code', 'State', 'County'])
Cms_Enrollment["Enrollment"].sum()

# Put Cms_Enrollment in pd = Nick
# Out:
# FIPS State County Code  State  County
# 1001.0                  AL     Autauga           6961
# 1003.0                  AL     Baldwin          35220
# 1005.0                  AL     Barbour           4576
# 1007.0                  AL     Bibb              3550
# 1009.0                  AL     Blount            9647
# 1011.0                  AL     Bullock           1455
# 1013.0                  AL     Butler            3530
# 1015.0                  AL     Calhoun          17134
# 1017.0                  AL     Chambers          6302
# 1019.0                  AL     Cherokee          5429
# 1021.0                  AL     Chilton           7087
# 1023.0                  AL     Choctaw           2949
# 1025.0                  AL     Clarke            4889
# 1027.0                  AL     Clay              2489
# 1029.0                  AL     Cleburne          2347
# 1031.0                  AL     Coffee            5886
# 1033.0                  AL     Colbert           9791
# ...

# %%
# Columns 2

df2.columns
# Out:
# Index(['SUMLEV', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME', 'YEAR', 'AGEGRP',
#        'TOT_POP', 'TOT_MALE', 'TOT_FEMALE', 'WA_MALE', 'WA_FEMALE', 'BA_MALE',
#        'BA_FEMALE', 'IA_MALE', 'IA_FEMALE', 'AA_MALE', 'AA_FEMALE', 'NA_MALE',
#        'NA_FEMALE', 'TOM_MALE', 'TOM_FEMALE', 'WAC_MALE', 'WAC_FEMALE',
#        'BAC_MALE', 'BAC_FEMALE', 'IAC_MALE', 'IAC_FEMALE', 'AAC_MALE',
#        'AAC_FEMALE', 'NAC_MALE', 'NAC_FEMALE', 'NH_MALE', 'NH_FEMALE',
#        'NHWA_MALE', 'NHWA_FEMALE', 'NHBA_MALE', 'NHBA_FEMALE', 'NHIA_MALE',
#        'NHIA_FEMALE', 'NHAA_MALE', 'NHAA_FEMALE', 'NHNA_MALE', 'NHNA_FEMALE',
#        'NHTOM_MALE', 'NHTOM_FEMALE', 'NHWAC_MALE', 'NHWAC_FEMALE',
#        'NHBAC_MALE', 'NHBAC_FEMALE', 'NHIAC_MALE', 'NHIAC_FEMALE',
#        'NHAAC_MALE', 'NHAAC_FEMALE', 'NHNAC_MALE', 'NHNAC_FEMALE', 'H_MALE',
#        'H_FEMALE', 'HWA_MALE', 'HWA_FEMALE', 'HBA_MALE', 'HBA_FEMALE',
#        'HIA_MALE', 'HIA_FEMALE', 'HAA_MALE', 'HAA_FEMALE', 'HNA_MALE',
# ...

# %%
# Read CSV population file

df2 = pd.read_csv("Population_Data.csv",encoding='iso-8859-1') 
df2.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    54571
# 1      50      1       1  Alabama  Autauga County     1       1     3579
# 2      50      1       1  Alabama  Autauga County     1       2     3991
# 3      50      1       1  Alabama  Autauga County     1       3     4290
# 4      50      1       1  Alabama  Autauga County     1       4     4290
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     26569       28002  ...        607          538         57           48
# 1      1866        1713  ...         77           56          9            5
# 2      2001        1990  ...         64           66          2            3
# 3      2171        2119  ...         51           57         13            7
# 4      2213        2077  ...         48           44          7            5
#
# ...

# %%
# Create New Dataframe

Population = df2[['STNAME', 'CTYNAME', 'YEAR', 'AGEGRP','TOT_POP', 'TOT_MALE', 'TOT_FEMALE']]
Population.head()
# Out:
#     STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  TOT_MALE  TOT_FEMALE
# 0  Alabama  Autauga County     1       0    54571     26569       28002
# 1  Alabama  Autauga County     1       1     3579      1866        1713
# 2  Alabama  Autauga County     1       2     3991      2001        1990
# 3  Alabama  Autauga County     1       3     4290      2171        2119
# 4  Alabama  Autauga County     1       4     4290      2213        2077

# %%
# Medicare vs Population (by state and by county)
# Attach FIPS dict = Sarah
# Compare 2016 and 2017 medicare enrollment
# Compare 2016 Medicare to inpatient data
# Compare Medicare enrollment in county to income (Use Census data) (higher medicare enrollement in count = higher income??)

Merged_Data =
